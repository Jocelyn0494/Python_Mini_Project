# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Data for plotting
t= np.arange(0.0,2.0,0.01)
s= 1 + np.sin(2*np.pi*t)

# %%
fig,ax=plt.subplots()
ax.plot(t,s)
ax.set(xlabel = 'X', ylabel= 'Y', title='Simple Line Plot')
# Out:
# [Text(0, 0.5, 'Y'), Text(0.5, 0, 'X'), Text(0.5, 1.0, 'Simple Line Plot')]
